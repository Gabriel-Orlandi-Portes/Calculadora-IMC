# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Orlandi-Portes/Calculadora-IMC/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# --- Carregar bases ---
df_order = pd.read_csv('/content/Order_semicolon.csv', sep=';')
df_campaign_queue = pd.read_csv('/content/CampaignQueue_semicolon.csv', sep=';')
df_campaign = pd.read_csv('/content/Campaign_semicolon.csv', sep=';')

print("✅")
# Out:
# ✅

# %%
# --- Informações gerais ---
print("\nDimensões:")
print("Orders:", df_order.shape)
print("CampaignQueue:", df_campaign_queue.shape)
print("Campaign:", df_campaign.shape)
# Out:
# Dimensões:
# Orders: (2000, 23)
# CampaignQueue: (5000, 16)
# Campaign: (2000, 14)

# %%
print("\nPrimeiras linhas Orders:")
display(df_order.head(7))
# Out:
# Primeiras linhas Orders:
#    id   companyId containerId         createdAt  customer displayId engineId  \
# 0   1  I0VP1DZXGU    AKVXT2FH  08/01/2025 15:47       525    O8CC98   E3R037
# 1   2  04MEUULZ6W    KKMY5TG5  03/11/2024 22:30       694    HJ99VA   EJVOBV
# 2   3  W2ZZS7CCZW    I87JLGTV  09/09/2024 05:49       491    XJJDH2   UDX1ZF
# 3   4  SQ5MBL8L24    W3ZXOQHO  22/05/2025 06:22       846    J8QDM3   30FLOC
# 4   5  0RCNJ6BRJD    NA0C0FOS  22/02/2025 01:23        77    H4LV73   QI3URN
# 5   6  XF32XPMU6N    NGNJYJIK  17/12/2024 14:54       463    WS9UVN   MIXWGY
# 6   7  0Q15FQJIT6    F5Q4MYIX  17/05/2025 16:51       625    XJA3WX   6ILJ42
#
#       engineName engineType                                     extraInfo  \
# 0    DirectOrder        POS  Adipisci maiores nam eius vero nesciunt sed.
# 1    DirectOrder        APP                                           NaN
# 2         KDSPro        POS                                           NaN
# ...

# %%
print("\nEstrutura Orders:")
df_order.info()
# Out:
# Estrutura Orders:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2000 non-null   int64
#  1   companyId             2000 non-null   object
#  2   containerId           2000 non-null   object
#  3   createdAt             2000 non-null   object
#  4   customer              2000 non-null   int64
#  5   displayId             2000 non-null   object
#  6   engineId              2000 non-null   object
#  7   engineName            2000 non-null   object
#  8   engineType            2000 non-null   object
#  9   extraInfo             819 non-null    object
#  10  integrated            2000 non-null   bool
#  11  integrationId         2000 non-null   int64
#  12  isTest                2000 non-null   bool
#  13  orderTiming           2000 non-null   object
# ...

# %%
print("\nEstrutura CampaignQueue:")
df_campaign_queue.info()
# Out:
# Estrutura CampaignQueue:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5000 non-null   int64
#  1   jobId            5000 non-null   int64
#  2   campaignId       5000 non-null   int64
#  3   storeId          5000 non-null   object
#  4   storeInstanceId  5000 non-null   object
#  5   customerId       5000 non-null   int64
#  6    phoneNumber     5000 non-null   object
#  7   scheduledAt      5000 non-null   object
#  8   sendAt           3288 non-null   object
#  9   status           5000 non-null   int64
#  10  message          5000 non-null   object
#  11  response         1588 non-null   object
#  12  createdAt        5000 non-null   object
#  13  createdBy        5000 non-null   object
#  14  updatedAt        5000 non-null   object
#  15  updatedBy        5000 non-null   object
# ...

# %%
print("\n Estrutura Campaign:")
df_campaign.info()
# Out:
#  Estrutura Campaign:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           2000 non-null   int64
#  1   segmentId    2000 non-null   int64
#  2   templateId   2000 non-null   int64
#  3   storeId      2000 non-null   object
#  4   name         2000 non-null   object
#  5   description  1595 non-null   object
#  6   badge        1681 non-null   object
#  7   type         2000 non-null   int64
#  8   status       2000 non-null   int64
#  9   isDefault    2000 non-null   bool
#  10  createdAt    2000 non-null   object
#  11  createdBy    2000 non-null   object
#  12  updatedAt    2000 non-null   object
#  13  updatedBy    2000 non-null   object
# dtypes: bool(1), int64(5), object(8)
# memory usage: 205.2+ KB
